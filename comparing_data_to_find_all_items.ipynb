# %%
import pandas as pd

# %%
df = pd.read_excel("data/comparing_data_food_items_last_month.xlsx")
# Out:
# c:\Users\NIKHU1\OneDrive - IKEA\Desktop\IKEA Projects\Disposables\env\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#                                                  Item  \
# 0                                 00331533 - espresso
# 1                     00343381 - Potato mashed, extra
# 2                00343965 - N Hot Beverage speciality
# 3                        00344644 - Burger vegetarian
# 4                      00346285 - Cake almond caramel
# ..                                                ...
# 64  90569605 - Salmon fillet cauliflower risotto/b...
# 65                               90585097 - hot drink
# 66  90585587 - strawberry fruit soft ice waffle co...
# 67                                                NaN
# 68  Applied filters:\nType is Compare RELATIVE per...
#
#     Items per 1000 customers  Receipts     Sales  Quantity
# 0                   4.685700     967.0   1712.15    1464.0
# 1                  55.268211   15336.0  34224.03   17268.0
# 2                   4.141595    1258.0   4505.71    1294.0
# 3                   2.886954     731.0   1343.32     902.0
# ...

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df[['batch_code','item_name']] = df['Item'].str.split(' - ', n = 1, expand=True)

# %%
df
# Out:
#                                                  Item  \
# 0                                 00331533 - espresso
# 1                     00343381 - Potato mashed, extra
# 2                00343965 - N Hot Beverage speciality
# 3                        00344644 - Burger vegetarian
# 4                      00346285 - Cake almond caramel
# ..                                                ...
# 62                                    90335857 - Soup
# 63                           90353846 - Pancake apple
# 64  90569605 - Salmon fillet cauliflower risotto/b...
# 65                               90585097 - hot drink
# 66  90585587 - strawberry fruit soft ice waffle co...
#
#     Items per 1000 customers  Receipts     Sales  Quantity batch_code  \
# 0                   4.685700     967.0   1712.15    1464.0   00331533
# 1                  55.268211   15336.0  34224.03   17268.0   00343381
# 2                   4.141595    1258.0   4505.71    1294.0   00343965
# ...

# %%
final_col = ['batch_code', 'item_name']
df = df[final_col]

# %%
df
# Out:
#    batch_code                                   item_name
# 0    00331533                                    espresso
# 1    00343381                        Potato mashed, extra
# 2    00343965                   N Hot Beverage speciality
# 3    00344644                           Burger vegetarian
# 4    00346285                         Cake almond caramel
# ..        ...                                         ...
# 62   90335857                                        Soup
# 63   90353846                               Pancake apple
# 64   90569605  Salmon fillet cauliflower risotto/bean mix
# 65   90585097                                   hot drink
# 66   90585587    strawberry fruit soft ice waffle cone CA
#
# [67 rows x 2 columns]

# %%
df.to_csv("cleaned_comparing_data_food_items_last_month.csv", index=False)
